# %% [markdown]
# 1. Flask is a lightweight and flexible web framework for Python. It is known for its simplicity and ease of use, allowing developers to quickly build web applications and APIs.
#
# Advantages of using Flask are:
# (a) Lightweight and Minimalistic: Flask is designed to be simple and lightweight, providing only the essential tools needed to get a web application up and running.
# (b) Flexible: Flask does not enforce any particular project or code layout, allowing developers to structure their applications as they see fit.
# (c) Extensible: Flask can be easily extended with numerous third-party libraries and plugins, enabling developers to add functionality as needed.
# (d) Easy to Learn: Flask’s straightforward and concise API makes it an excellent choice for beginners and allows for quick development.

# %% [markdown]
# 2.
# ![image.png](attachment:385992c8-8047-4b3c-9b0f-12d6803c7e49.png)

# %% [markdown]
# 3. App routing in Flask is the mechanism to map URLs to specific functions in the Flask application. These functions are known as view functions and define what should be displayed when a user navigates to a particular URL.
#
# We do app routing for following reasons:
# (a)Define URL Patterns: Routes allow developers to define the URL structure of their web applications.
# (b)Associate URLs with Functions: Routes map specific URLs to the functions that handle the requests for those URLs.
# (c)Create User-Friendly URLs: Routes enable the creation of user-friendly URLs that are easy to remember and navigate.
# (d)Control Application Flow: Routes help control the flow of the application, ensuring that the correct view function is called for each URL.

# %% [markdown]
# 4.
# ![image.png](attachment:a43ab334-58e5-463d-b026-7b5643ab5ee4.png)

# %% [markdown]
# 5. The url_for() function is used in Flask to build a URL to a specific function. This is useful for generating dynamic URLs and avoiding hardcoding URLs in the application.
#
# from flask import Flask, url_for
#
# app = Flask(__name__)
#
# @app.route('/')
# def home():
#     return '''
#     <a href="{}">Welcome Page</a>
#     '''.format(url_for('welcome'))
#
# @app.route('/welcome')
# def welcome():
#     return 'Welcome to ABC Corporation'
#
# if __name__ == '__main__':
#     app.run()
